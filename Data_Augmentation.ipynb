# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
import numpy as np

X = np.load('X.npy')
Y = np.load('Y.npy')

print(X.shape)
print(Y.shape)
# Out:
# (2062, 64, 64)
# (2062, 10)

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
test_random = np.random.randint(X.shape[0], size=9)
print(test_random)
# Out:
# [1048  647  228  826 1175 1518  947  989  519]

# %%
import matplotlib.pyplot as plt

f = plt.figure()
plt.rcParams["figure.figsize"] = [10, 10]
random_sign = np.random.choice(X.shape[0],9)
print(random_sign)

for a in range (9) :
    f.add_subplot(3,3,(a+1))
    plt.imshow(X[random_sign[a]])

plt.show(block=True)
# Out:
# <img src="data:image/png;base64,..." width="940">
# [1752  860 1554 1674 1694 1069 1990 1978  873]

# %%
from keras.preprocessing.image import ImageDataGenerator

# reshape to be [samples][width][height][channels]
X_4D = X.reshape((X.shape[0],X.shape[1], X.shape[2], 1))
print (X_4D.shape)

X_4D_r = X[random_sign].reshape((9,X.shape[1], X.shape[2], 1))
print (X_4D_r.shape)

# define data preparation
datagen = ImageDataGenerator(rotation_range=90)

# fit parameters from data
datagen.fit(X_4D)
# Out:
# (2062, 64, 64, 1)
# (9, 64, 64, 1)

# %%
f = plt.figure()
plt.rcParams["figure.figsize"] = [10, 10]
i=1
for a in datagen.flow(X_4D, batch_size=1):
    f.add_subplot(10,10,i)
    plt.imshow(a.reshape((X.shape[1], X.shape[2])))
    i=i+1
    if i==101:
        break
plt.show(block=True)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
aug_X_4D = datagen.flow(X_4D, batch_size = 1)

# %%
aug_X_4D
